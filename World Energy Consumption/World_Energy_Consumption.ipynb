# %% [markdown]
# # World Energy Consumption

# %%
import pandas as pd
import numpy as np

from bokeh.io import output_notebook
from bokeh.plotting import figure, show

# %%
#@title Loading Data
LoadCsv = 'https://raw.githubusercontent.com/AshrafulPatHan/notebook/main/World%20Energy%20Consumption/World%20Energy%20Consumption.csv'
data = pd.read_csv(LoadCsv)
data.head()
# Out:
#          country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  ASEAN (Ember)  2000      NaN         NaN  NaN                      NaN
# 1  ASEAN (Ember)  2001      NaN         NaN  NaN                      NaN
# 2  ASEAN (Ember)  2002      NaN         NaN  NaN                      NaN
# 3  ASEAN (Ember)  2003      NaN         NaN  NaN                      NaN
# 4  ASEAN (Ember)  2004      NaN         NaN  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# ...

# %%
output_notebook()

# %%
#@title year to biofuel_electricity

p = figure(title="year vs biofuel_electricity",width=400, height=400)

p.scatter(data['year'], data['biofuel_electricity'], size=20, color="navy", alpha=0.5)

p.xaxis.axis_label = "year"
p.yaxis.axis_label = "biofuel_electricity"

show(p)
# Out:
#   <div id="a748b153-d4bf-4d90-a85a-99de098527c1" data-root-id="p1008" style="display: contents;"></div>

# %% [markdown]
# ## Sort Country

# %%
High_Population = data[(data['year'] == 2022) & (data['population'] > 160000000)]
High_Population
# Out:
#                              country  year iso_code    population  gdp  \
# 267                           Africa  2022      NaN  1.426737e+09  NaN
# 1271                            Asia  2022      NaN  4.721383e+09  NaN
# 2125                      Bangladesh  2022      BGD  1.711864e+08  NaN
# 2975                          Brazil  2022      BRA  2.153135e+08  NaN
# 4405                           China  2022      CHN  1.425887e+09  NaN
# 6684                          Europe  2022      NaN  7.448070e+08  NaN
# 7005             European Union (27)  2022      NaN  4.473159e+08  NaN
# 8758           High-income countries  2022      NaN  1.224122e+09  NaN
# 9288                           India  2022      IND  1.417173e+09  NaN
# 9411                       Indonesia  2022      IDN  2.755013e+08  NaN
# 11045           Low-income countries  2022      NaN  7.175874e+08  NaN
# 11168  Lower-middle-income countries  2022      NaN  3.447031e+09  NaN
# ...

# %%
# 3. Sort the results by population from highest to lowest
sorted_High_Population = High_Population.sort_values(by="population", ascending=False)
sorted_High_Population
# Out:
#                              country  year iso_code    population  gdp  \
# 21631                          World  2022      NaN  7.975105e+09  NaN
# 1271                            Asia  2022      NaN  4.721383e+09  NaN
# 11168  Lower-middle-income countries  2022      NaN  3.447031e+09  NaN
# 20949  Upper-middle-income countries  2022      NaN  2.555056e+09  NaN
# 267                           Africa  2022      NaN  1.426737e+09  NaN
# 4405                           China  2022      CHN  1.425887e+09  NaN
# 9288                           India  2022      IND  1.417173e+09  NaN
# 8758           High-income countries  2022      NaN  1.224122e+09  NaN
# 6684                          Europe  2022      NaN  7.448070e+08  NaN
# 11045           Low-income countries  2022      NaN  7.175874e+08  NaN
# 14072                  North America  2022      NaN  6.003237e+08  NaN
# 7005             European Union (27)  2022      NaN  4.473159e+08  NaN
# ...

# %% [markdown]
# ## Contry Details

# %%
#@title Add Country Name
CountryName = 'Bangladesh' #@param {type:"string"}
country = data[data['country'] == CountryName].copy()
country
# Out:
#          country  year iso_code   population           gdp  \
# 2003  Bangladesh  1900      BGD   26849595.0           NaN
# 2004  Bangladesh  1901      BGD   26958449.0           NaN
# 2005  Bangladesh  1902      BGD   27067609.0           NaN
# 2006  Bangladesh  1903      BGD   27177073.0           NaN
# 2007  Bangladesh  1904      BGD   27286841.0           NaN
# ...          ...   ...      ...          ...           ...
# 2121  Bangladesh  2018      BGD  163683952.0  6.865218e+11
# 2122  Bangladesh  2019      BGD  165516224.0           NaN
# 2123  Bangladesh  2020      BGD  167420944.0           NaN
# 2124  Bangladesh  2021      BGD  169356240.0           NaN
# 2125  Bangladesh  2022      BGD  171186368.0           NaN
#
#       biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 2003                      NaN                      NaN
# 2004                      NaN                      NaN
# 2005                      NaN                      NaN
# ...

# %%
country[['year', 'population']]
# Out:
#       year   population
# 2003  1900   26849595.0
# 2004  1901   26958449.0
# 2005  1902   27067609.0
# 2006  1903   27177073.0
# 2007  1904   27286841.0
# ...    ...          ...
# 2121  2018  163683952.0
# 2122  2019  165516224.0
# 2123  2020  167420944.0
# 2124  2021  169356240.0
# 2125  2022  171186368.0
#
# [123 rows x 2 columns]

# %%
display(country['gdp'])
# Out:
# 2003             NaN
# 2004             NaN
# 2005             NaN
# 2006             NaN
# 2007             NaN
#             ...
# 2121    6.865218e+11
# 2122             NaN
# 2123             NaN
# 2124             NaN
# 2125             NaN
# Name: gdp, Length: 123, dtype: float64
